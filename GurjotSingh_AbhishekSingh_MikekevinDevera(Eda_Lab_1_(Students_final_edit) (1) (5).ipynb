# %% [markdown]
# # EDA Lab 1: Data Exploration & Visualization

# %% [markdown]
# ##### In this lab, we will be going over some basic data analysis techniques like feature selection, finding the correlation between different features and visualizing our data to understand it better.

# %% [markdown]
# ##### Domain knowledge: The lab does not require any domain knowledge of basketball or what the column names stand for. In fact, it assumes you do not have any knowledge about basketball stats. However, you will see how domain knowledge helps as you progress forward.

# %% [markdown]
# Outcomes:
# - Find “interesting” features about data from looking at tables and statistics about the data.
# - Describe how visualization can be used as a data exploration tool and for verification purposes.
# - Create some useful types of visualization

# %% [markdown]
# #### Importing libraries and loading data

# %% [markdown]
# The data for this lab can be downloaded from here: https://www.kaggle.com/rikdifos/2018-2019-nba-champion-toronto-raptors-analysis/data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

##
#Loading playoffs data
df = pd.read_csv('raptors_regulars.csv')

#Setting up notebook so that all columns are displayed
pd.set_option('display.max_columns', None)

# %% [markdown]
# ##### Observing data

# %%
df.head(7)
# Out:
#   TEAM        DATE      MATCHUP W/L  MIN  PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 0  TOR  01/13/2019    TOR @ WAS   W  290  140   49  104  47.1   13   36  36.1
# 1  TOR  11/29/2018  TOR vs. GSW   W  265  131   47   90  52.2   15   38  39.5
# 2  TOR  02/13/2019  TOR vs. WAS   W  241  129   44   92  47.8   16   38  42.1
# 3  TOR  10/30/2018  TOR vs. PHI   W  240  129   47   92  51.1   11   27  40.7
# 4  TOR  03/18/2019  TOR vs. NYK   W  240  128   49   88  55.7   17   40  42.5
# 5  TOR  11/10/2018  TOR vs. NYK   W  239  128   42   79  53.2   14   35  40.0
# 6  TOR  03/08/2019    TOR @ NOP   W  240  127   53   99  53.5   13   37  35.1
#
#    FTM  FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  PF  +/-
# 0   29   36  80.6    17    42   59   24   16    8   21  27    2
# 1   22   24  91.7     7    30   37   25    5    6   14  23    3
# 2   25   30  83.3     9    43   52   32    8    8   14  27    9
# 3   24   28  85.7     9    34   43   29   13    6   15  26   17
# 4   13   22  59.1     5    45   50   36    5    6   14  22   36
# 5   30   40  75.0    12    34   46   24    8    4   15  20   16
# 6    8    9  88.9     7    44   51   31   10   12   16  14   23

# %%
df.shape
# Out:
# (82, 24)

# %% [markdown]
# ##### Checking data type for each column

# %%
df.dtypes
# Out:
# TEAM        object
# DATE        object
# MATCHUP     object
# W/L         object
# MIN          int64
# PTS          int64
# FGM          int64
# FGA          int64
# FG%        float64
# 3PM          int64
# 3PA          int64
# 3P%        float64
# FTM          int64
# FTA          int64
# FT%        float64
# OREB         int64
# DREB         int64
# REB          int64
# AST          int64
# STL          int64
# BLK          int64
# TOV          int64
# PF           int64
# +/-          int64
# dtype: object

# %% [markdown]
# ### Lab Activity 1: Data Preprocessing

# %% [markdown]
# ##### [Q] The `'W/L'` column tells us whether the team won or lost the game. However, since the `'W/L'` column is in `text(object)` format, we cannot perform proper statistical analysis. Thus, we need to change it, so $1$ represents a win and $0$ represents a loss.

# %%
#Hint: Changing the values of the column does not change the data type. You need to alter both, the values and the data type the column represents

# %%
df.loc[df["W/L"]=='W', 'W/L']=1
df.loc[df["W/L"]=="L", "W/L"]=0
df["W/L"]=df["W/L"].astype(int)

# %% [markdown]
# ##### [Q] Check the data types again.

# %%
df.dtypes
# Out:
# TEAM        object
# DATE        object
# MATCHUP     object
# W/L          int64
# MIN          int64
# PTS          int64
# FGM          int64
# FGA          int64
# FG%        float64
# 3PM          int64
# 3PA          int64
# 3P%        float64
# FTM          int64
# FTA          int64
# FT%        float64
# OREB         int64
# DREB         int64
# REB          int64
# AST          int64
# STL          int64
# BLK          int64
# TOV          int64
# PF           int64
# +/-          int64
# dtype: object

# %% [markdown]
# ##### [Q] Convert `'DATE'` column to [`datetime` format](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html).

# %%
df['DATE']=pd.to_datetime(df['DATE'])

# %%
# Out:
#    TEAM       DATE      MATCHUP  W/L  MIN  PTS  FGM  FGA   FG%  3PM  3PA  \
# 0   TOR 2019-01-13    TOR @ WAS    1  290  140   49  104  47.1   13   36
# 1   TOR 2018-11-29  TOR vs. GSW    1  265  131   47   90  52.2   15   38
# 2   TOR 2019-02-13  TOR vs. WAS    1  241  129   44   92  47.8   16   38
# 3   TOR 2018-10-30  TOR vs. PHI    1  240  129   47   92  51.1   11   27
# 4   TOR 2019-03-18  TOR vs. NYK    1  240  128   49   88  55.7   17   40
# ..  ...        ...          ...  ...  ...  ...  ...  ...   ...  ...  ...
# 77  TOR 2018-12-30  TOR vs. CHI    1  239   95   34   92  37.0    9   33
# 78  TOR 2018-11-20    TOR @ ORL    1  240   93   39   87  44.8    9   34
# 79  TOR 2019-01-31  TOR vs. MIL    0  240   92   37   93  39.8    7   27
# 80  TOR 2018-12-28    TOR @ ORL    0  240   87   28   95  29.5   12   34
# 81  TOR 2018-12-16    TOR @ DEN    0  241   86   35   88  39.8    7   35
#
#      3P%  FTM  FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  PF  +/-
# 0   36.1   29   36  80.6    17    42   59   24   16    8   21  27    2
# 1   39.5   22   24  91.7     7    30   37   25    5    6   14  23    3
# 2   42.1   25   30  83.3     9    43   52   32    8    8   14  27    9
# 3   40.7   24   28  85.7     9    34   43   29   13    6   15  26   17
# 4   42.5   13   22  59.1     5    45   50   36    5    6   14  22   36
# ..   ...  ...  ...   ...   ...   ...  ...  ...  ...  ...  ...  ..  ...
# 77  27.3   18   20  90.0    17    35   52   17    5    8   11  15    6
# 78  26.5    6    8  75.0     6    37   43   23    7    5   16  19    2
# 79  25.9   11   13  84.6     8    31   39   16    9    4   16  20  -13
# 80  35.3   19   24  79.2    14    27   41   18    4   10   11  21  -29
# 81  20.0    9   14  64.3    13    38   51   13    5    4   11  16   -9
#
# [82 rows x 24 columns]

# %% [markdown]
# ##### [Q] Add a column `'DELTA'` with the delta time in days. That is, the number of days between matches.

# %%
df_2 = df.sort_values(by="DATE") #Sorting dataframe by DATE Column
df_2["DELTA"]= df_2["DATE"].diff() #Creating new column and calculating the differences between consecutive dates
#using diff() function for calculates difference of each elements
df_2["DELTA"].fillna( '0' ,inplace = True) #fillna() is a function used to replace the missing values. However, the inplace=true parameter that changes are applied directly in the dataframe.
df_2
# Out:
#    TEAM       DATE      MATCHUP  W/L  MIN  PTS  FGM  FGA   FG%  3PM  3PA  \
# 43  TOR 2018-10-17  TOR vs. CLE    1  239  116   45   92  48.9   14   33
# 49  TOR 2018-10-19  TOR vs. BOS    1  239  113   43   92  46.7   13   35
# 40  TOR 2018-10-20    TOR @ WAS    1  240  117   39   88  44.3   10   29
# 8   TOR 2018-10-22  TOR vs. CHA    1  241  127   50   87  57.5   15   39
# 51  TOR 2018-10-24  TOR vs. MIN    1  239  112   46   89  51.7   11   32
# ..  ...        ...          ...  ...  ...  ...  ...  ...   ...  ...  ...
# 25  TOR 2019-04-01  TOR vs. ORL    1  240  121   42   84  50.0   19   37
# 44  TOR 2019-04-03    TOR @ BKN    1  239  115   44  105  41.9   15   38
# 52  TOR 2019-04-05    TOR @ CHA    0  241  111   43   80  53.8    9   26
# 38  TOR 2019-04-07  TOR vs. MIA    1  264  117   39   87  44.8   16   41
# 29  TOR 2019-04-09    TOR @ MIN    1  240  120   46   88  52.3   16   37
#
#      3P%  FTM  FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  PF  +/-  DELTA
# 43  42.4   12   20  60.0     8    35   43   21    6    7    9  29   12 0 days
# 49  37.1   14   19  73.7    12    37   49   24    3    3   12  19   12 2 days
# 40  34.5   29   36  80.6    14    38   52   21    5    5   17  29    4 1 days
# 8   38.5   12   14  85.7     5    41   46   36   10    8   13  21   21 2 days
# 51  34.4    9   12  75.0    11    33   44   26    9    8   16  18    7 2 days
# ..   ...  ...  ...   ...   ...   ...  ...  ...  ...  ...  ...  ..  ...    ...
# 25  51.4   18   22  81.8     6    33   39   31    9    8   14  20   12 2 days
# 44  39.5   12   14  85.7    17    35   52   29    9    1    7  16   10 2 days
# 52  34.6   16   20  80.0     5    38   43   27    2    5   14  17   -2 2 days
# 38  39.0   23   27  85.2     4    43   47   26    7    5   11  17    8 2 days
# 29  43.2   12   17  70.6     7    47   54   24   10    5   18  17   20 2 days
#
# [82 rows x 25 columns]

# %% [markdown]
# This dataset is now preprocessed and in a correct format.

# %% [markdown]
# ### Lab Activity Two: Statistical Analysis & Visualizations

# %% [markdown]
# ##### [Q] Scatter plots are a useful method to observe relationships between variables. Plot a scatter plot of `'FGM'` (Y-axis) vs `'PTS'` (X-axis).

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['PTS'],df['FGM'] )
plt.xlabel('PTS', fontsize = 12, fontweight='bold')
plt.ylabel('FGM', fontsize = 12, fontweight='bold')
plt.title('Scatter Plot', fontsize = 15, fontweight='bold')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### [Q] Describe the relationship between Field Goals Made (`'FGM'`) and Points Scored (`'PTS'`). What can you observe?

# %% [raw]
# We can observe that it shows a 'High Positive Correlation'.
#
# ---
#
#
#
# ---

# %% [markdown]
# ##### [Q] Let's observe the [correlation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) between each column

# %%
#Make a new dataframe containing the correlations. Tip: The correlations of the features in your dataset can be simply obtained by using pandas_dataframe.corr()
correaltion_matrix = df.corr()
print(correaltion_matrix)
# Out:
#            W/L       MIN       PTS       FGM       FGA       FG%       3PM  \
# W/L   1.000000 -0.075488  0.575034  0.432612 -0.035753  0.386880  0.276205
# MIN  -0.075488  1.000000  0.205407  0.047877  0.209642 -0.092809  0.038488
# PTS   0.575034  0.205407  1.000000  0.772660  0.011150  0.671907  0.446822
# FGM   0.432612  0.047877  0.772660  1.000000  0.160288  0.769739  0.123228
# FGA  -0.035753  0.209642  0.011150  0.160288  1.000000 -0.501263 -0.208453
# FG%   0.386880 -0.092809  0.671907  0.769739 -0.501263  1.000000  0.250006
# 3PM   0.276205  0.038488  0.446822  0.123228 -0.208453  0.250006  1.000000
# 3PA   0.000122  0.114129  0.083493 -0.099486  0.247240 -0.239107  0.578110
# 3P%   0.303570 -0.034957  0.482326  0.197949 -0.408065  0.443555  0.848788
# FTM   0.212808  0.281027  0.358861 -0.218892 -0.102261 -0.121820  0.013550
# FTA   0.232450  0.232236  0.334081 -0.217540 -0.116602 -0.109766  0.014242
# FT%  -0.047695  0.105981  0.122893  0.044170  0.016916  0.028788  0.018406
# OREB -0.074823  0.062474 -0.122107 -0.173898  0.614249 -0.539124 -0.246400
# DREB  0.340098  0.137884  0.329554  0.367641  0.157469  0.200536  0.164125
# REB   0.216745  0.152323  0.175580  0.169707  0.550958 -0.215938 -0.041433
# AST   0.376716 -0.045692  0.554875  0.566493  0.055739  0.457366  0.485640
# STL   0.331385  0.177722  0.192245  0.196000  0.214096  0.025679 -0.065338
# BLK   0.107905  0.050830  0.023599  0.059442 -0.081499  0.110491  0.109966
# TOV  -0.103160  0.208603  0.045593  0.080031 -0.250715  0.226131  0.037753
# PF    0.065232  0.208197  0.306924  0.118434  0.043296  0.067450  0.175792
# +/-   0.775046 -0.118805  0.638127  0.601160 -0.021792  0.525421  0.425918
#
#            3PA       3P%       FTM       FTA       FT%      OREB      DREB  \
# W/L   0.000122  0.303570  0.212808  0.232450 -0.047695 -0.074823  0.340098
# MIN   0.114129 -0.034957  0.281027  0.232236  0.105981  0.062474  0.137884
# PTS   0.083493  0.482326  0.358861  0.334081  0.122893 -0.122107  0.329554
# FGM  -0.099486  0.197949 -0.218892 -0.217540  0.044170 -0.173898  0.367641
# FGA   0.247240 -0.408065 -0.102261 -0.116602  0.016916  0.614249  0.157469
# FG%  -0.239107  0.443555 -0.121820 -0.109766  0.028788 -0.539124  0.200536
# 3PM   0.578110  0.848788  0.013550  0.014242  0.018406 -0.246400  0.164125
# 3PA   1.000000  0.080137 -0.047243 -0.042216  0.000861  0.079981  0.202491
# 3P%   0.080137  1.000000  0.055455  0.041181  0.064172 -0.343140  0.054216
:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correaltion_matrix = df.corr()

# %% [markdown]
# ##### [Q] A heatmap is a great way to visualize the correlations. Plot a heatmap using the [seaborn]((https://seaborn.pydata.org/generated/seaborn.heatmap.html)) library. Note: You may need to install seaborn using 'pip install seaborn' on the anaconda prompt interface.

# %%
import seaborn as sns

sns.heatmap(correaltion_matrix)
# Out:
# <Axes: >

# %% [markdown]
# ##### [Q] Naturally, we should first try to observe what game stats (features) help the team towards a victory or a loss ($1$ or $0$ in the `'W/L'` column). Order the correlations dataframe by the `'W/L'` column.

# %%
#Sort by descending values and display/view the sorted table
df_sort_correaltion  = correaltion_matrix.sort_values(by='W/L' , ascending = False)
df_sort_correaltion
# Out:
#            W/L       MIN       PTS       FGM       FGA       FG%       3PM  \
# W/L   1.000000 -0.075488  0.575034  0.432612 -0.035753  0.386880  0.276205
# +/-   0.775046 -0.118805  0.638127  0.601160 -0.021792  0.525421  0.425918
# PTS   0.575034  0.205407  1.000000  0.772660  0.011150  0.671907  0.446822
# FGM   0.432612  0.047877  0.772660  1.000000  0.160288  0.769739  0.123228
# FG%   0.386880 -0.092809  0.671907  0.769739 -0.501263  1.000000  0.250006
# AST   0.376716 -0.045692  0.554875  0.566493  0.055739  0.457366  0.485640
# DREB  0.340098  0.137884  0.329554  0.367641  0.157469  0.200536  0.164125
# STL   0.331385  0.177722  0.192245  0.196000  0.214096  0.025679 -0.065338
# 3P%   0.303570 -0.034957  0.482326  0.197949 -0.408065  0.443555  0.848788
# 3PM   0.276205  0.038488  0.446822  0.123228 -0.208453  0.250006  1.000000
# FTA   0.232450  0.232236  0.334081 -0.217540 -0.116602 -0.109766  0.014242
# REB   0.216745  0.152323  0.175580  0.169707  0.550958 -0.215938 -0.041433
# FTM   0.212808  0.281027  0.358861 -0.218892 -0.102261 -0.121820  0.013550
# BLK   0.107905  0.050830  0.023599  0.059442 -0.081499  0.110491  0.109966
# PF    0.065232  0.208197  0.306924  0.118434  0.043296  0.067450  0.175792
# 3PA   0.000122  0.114129  0.083493 -0.099486  0.247240 -0.239107  0.578110
# FGA  -0.035753  0.209642  0.011150  0.160288  1.000000 -0.501263 -0.208453
# FT%  -0.047695  0.105981  0.122893  0.044170  0.016916  0.028788  0.018406
# OREB -0.074823  0.062474 -0.122107 -0.173898  0.614249 -0.539124 -0.246400
# MIN  -0.075488  1.000000  0.205407  0.047877  0.209642 -0.092809  0.038488
# TOV  -0.103160  0.208603  0.045593  0.080031 -0.250715  0.226131  0.037753
#
#            3PA       3P%       FTM       FTA       FT%      OREB      DREB  \
# W/L   0.000122  0.303570  0.212808  0.232450 -0.047695 -0.074823  0.340098
# +/-   0.100102  0.409729 -0.028239  0.001423 -0.043511 -0.116633  0.478098
# PTS   0.083493  0.482326  0.358861  0.334081  0.122893 -0.122107  0.329554
# FGM  -0.099486  0.197949 -0.218892 -0.217540  0.044170 -0.173898  0.367641
# FG%  -0.239107  0.443555 -0.121820 -0.109766  0.028788 -0.539124  0.200536
# MIN   0.152323 -0.045692  0.177722  0.050830  0.208603  0.208197 -0.118805
# TOV   0.143649 -0.053276  0.189536  0.080011  1.000000  0.104269 -0.042890

# %% [markdown]
# ##### Let's now take a look at the features closely and their definitions.

# %% [markdown]
# `MIN`: Minutes played
#
# `PTS`: Points scored by the team
#
# `FGM`: Field goals made (shots taken that went in the basket, 3-pointers not included)
#
# `FGA`: Field goals attempt (total shots taken, 3-pointers not included)
#
# `FG%`: FGM divided by FGA
#
# `3PM`: Three pointers made (3 pointers that went in)
#
# `3PA`: Three pointers attempted (total three point shots taken)
#
# `3P%`: 3PM/3PA
#
# `FTM`: Free throws made
#
# `FTA`: Free throws attempted
#
# `FT%`: FTM/FTA
#
# `OREB`: Offensive rebound (The team shoots the ball, does not get it
# in but is able to rebound the ball back)
#
# `DREB`: Defensive rebound (The OTHER teams shoots the ball, does not get it in and OUR team is able to rebound the ball)
#
# `REB`: total rebounds (OREB+DREB)
#
# `AST`: Assists
#
# `STL`: Steals
#
# `BLK`: Blocks
#
# `TOV`: Turnovers (how many times the team lost the ball)
#
# `PF`: Personal Fouls
#
# `+/-`: Can be ignored

# %% [markdown]
# #### Now that you have definitions of the features, go back and observe the sorted correlations table.

# %% [markdown]
# - The `'TOV'` feature is negatively correlated, which makes sense given by definition, the more times a team loses the ball, the lower the chance of them winning the game.

# %% [markdown]
# - The `'PTS'` feature is positively correlated; the more points the team scored, the higher the chance of winning.

# %% [markdown]
# - Interestingly, the number of three point attempts made (`'3PA'`) has the least effect on the game's outcome (correlation close to $0$).

# %% [markdown]
# Continuing your observation of correlations between the features and the W/L column, the correlations statistics start to make sense.

# %% [markdown]
# **Domain knowledge:** This is where domain knowledge comes into use. Having the background information of the dataset you are working with can significantly help in data analysis and machine learning tasks. The knowledge level required can vary depending on the challenge being solved; From intermediate (this lab) to advanced (Disease detection in chest x-rays using AI). It is always a good idea to go out of your way to gain knowledge in the domain you are working in and understand the data being used.

# %% [markdown]
# #### More Visualizations

# %% [markdown]
# ##### [Q] Going back to our original dataframe (not the correlations `df`), plot a histogram of the points scored (`'PTS'` column).

# %%
# Hint: Don't set a specific bin value for this visualization, let matplotlib determine it automatically. Though this isn't always the case.
# Tip: Increase the font-size of your labels for a clearer view.
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['PTS'],  color='red', edgecolor='black')
plt.xlabel('PTS', fontsize = 12, fontweight='bold')
plt.ylabel('Frequency', fontsize = 12, fontweight='bold')
plt.title('Histogram', fontsize = 20, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### [Q] What is the value of the points scored in a game that occur the most?

# %% [raw]
# The most occured points is 120.
#
# ---

# %% [markdown]
# ##### [Q] Now plot a simple line graph of the points scored (`'PTS'` column) over time.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['PTS'], marker='o',color='blue', linestyle='-')
plt.xlabel('PTS', fontsize = 12, fontweight='bold')
plt.ylabel('FREQUENCY',fontsize = 12, fontweight='bold')
plt.title('Line Plot', fontsize = 15, fontweight='bold')
plt.grid(True)
plt.tight_layout()
plt.show()
